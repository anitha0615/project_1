# %%
import pandas as pd

# %%
csv_path = "Resources/zillow_data.csv"
zillow_df = pd.read_csv(csv_path)

zillow_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 0     61148         0        8701        zip        NJ    NJ      Lakewood
# 1     91982         1       77494        zip        TX    TX          Katy
# 2     91940         2       77449        zip        TX    TX          Katy
# 3     62080         3       11368        zip        NY    NY      New York
# 4     92593         4       78660        zip        TX    TX  Pflugerville
#
#                                    Metro        CountyName     2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  132227.158462
# 1   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  222152.961968
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County  112898.162200
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County   72326.248058
# 4       Austin-Round Rock-Georgetown, TX     Travis County  181767.202252
#
#    ...     2022-06-30     2022-07-31     2022-08-31     2022-09-30  \
# ...

# %%
first_df = zillow_df[zillow_df["StateName"] == "TX"]
first_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 1     91982         1       77494        zip        TX    TX          Katy
# 2     91940         2       77449        zip        TX    TX          Katy
# 4     92593         4       78660        zip        TX    TX  Pflugerville
# 6     93144         6       79936        zip        TX    TX       El Paso
# 9     91733         9       77084        zip        TX    TX       Houston
#
#                                   Metro        CountyName     2000-01-31  ...  \
# 1  Houston-The Woodlands-Sugar Land, TX  Fort Bend County  222152.961968  ...
# 2  Houston-The Woodlands-Sugar Land, TX     Harris County  112898.162200  ...
# 4      Austin-Round Rock-Georgetown, TX     Travis County  181767.202252  ...
# 6                           El Paso, TX    El Paso County   94748.800128  ...
# 9  Houston-The Woodlands-Sugar Land, TX     Harris County  112974.543577  ...
#
# ...

# %%
texas_df = first_df[first_df["RegionType"]=="zip"]
texas_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 1     91982         1       77494        zip        TX    TX          Katy
# 2     91940         2       77449        zip        TX    TX          Katy
# 4     92593         4       78660        zip        TX    TX  Pflugerville
# 6     93144         6       79936        zip        TX    TX       El Paso
# 9     91733         9       77084        zip        TX    TX       Houston
#
#                                   Metro        CountyName     2000-01-31  ...  \
# 1  Houston-The Woodlands-Sugar Land, TX  Fort Bend County  222152.961968  ...
# 2  Houston-The Woodlands-Sugar Land, TX     Harris County  112898.162200  ...
# 4      Austin-Round Rock-Georgetown, TX     Travis County  181767.202252  ...
# 6                           El Paso, TX    El Paso County   94748.800128  ...
# 9  Houston-The Woodlands-Sugar Land, TX     Harris County  112974.543577  ...
#
# ...

# %%
txquarterly_df = texas_df[["SizeRank", "RegionName", "RegionType", "State", "City", "Metro", "CountyName", "2017-03-31", "2017-06-30","2017-09-30","2017-12-31","2018-03-31", "2018-06-30","2018-09-30","2018-12-31","2019-03-31", "2019-06-30","2019-09-30","2019-12-31","2020-03-31", "2020-06-30","2020-09-30","2020-12-31","2021-03-31", "2021-06-30","2021-09-30","2021-12-31","2022-03-31", "2022-06-30","2022-09-30","2022-12-31","2023-03-31"]]
txquarterly_df
# Out:
#        SizeRank  RegionName RegionType State          City  \
# 1             1       77494        zip    TX          Katy
# 2             2       77449        zip    TX          Katy
# 4             4       78660        zip    TX  Pflugerville
# 6             6       79936        zip    TX       El Paso
# 9             9       77084        zip    TX       Houston
# ...         ...         ...        ...   ...           ...
# 26979     39809       77475        zip    TX      Sheridan
# 26986     39809       77470        zip    TX      Columbus
# 26992     39809       77661        zip    TX           NaN
# 26998     39809       76370        zip    TX      Megargel
# 27008     39809       77451        zip    TX  East Bernard
#
#                                       Metro        CountyName     2017-03-31  \
# 1      Houston-The Woodlands-Sugar Land, TX  Fort Bend County  342646.794913
# 2      Houston-The Woodlands-Sugar Land, TX     Harris County  183125.433407
# ...

# %%
txquarterly_df.count()
columns_to_drop = ["2017-03-31", "2017-06-30","2017-09-30","2017-12-31","2018-03-31", "2018-06-30","2018-09-30","2018-12-31","2019-03-31", "2019-06-30","2019-09-30","2019-12-31","2020-03-31", "2020-06-30","2020-09-30","2020-12-31","2021-03-31", "2021-06-30","2021-09-30","2021-12-31","2022-03-31", "2022-06-30","2022-09-30","2022-12-31","2023-03-31"]

# %%
txclean_df = txquarterly_df.dropna(how="any")
txclean_df.count()
# Out:
# SizeRank      1035
# RegionName    1035
# RegionType    1035
# State         1035
# City          1035
# Metro         1035
# CountyName    1035
# 2017-03-31    1035
# 2017-06-30    1035
# 2017-09-30    1035
# 2017-12-31    1035
# 2018-03-31    1035
# 2018-06-30    1035
# 2018-09-30    1035
# 2018-12-31    1035
# 2019-03-31    1035
# 2019-06-30    1035
# 2019-09-30    1035
# 2019-12-31    1035
# 2020-03-31    1035
# 2020-06-30    1035
# 2020-09-30    1035
# 2020-12-31    1035
# 2021-03-31    1035
# 2021-06-30    1035
# 2021-09-30    1035
# 2021-12-31    1035
# 2022-03-31    1035
# 2022-06-30    1035
# 2022-09-30    1035
# 2022-12-31    1035
# 2023-03-31    1035
# dtype: int64
